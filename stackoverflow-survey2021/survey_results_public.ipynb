# %% [markdown]
# # Stack Overflow Annual Developer Survey
#
# <h3>
#  We'll be using Stack Overflowover website with 70,000 responses fielded from over 180 countries, our Annual Developer Survey examines all aspects of the developer experience from learning to code to their favorite technologies to version control and the workplace experience of professional developers. as an example. You can find it here:</h3>
#
# <a><h3>https://insights.stackoverflow.com/survey</h3></a>
#
# <h4><b>data manipulation with groupby()</b></h4>

# %% [markdown]
# # Filtering :

# %%
# Importing libraries

import numpy as np
import pandas as pd

import os

# os.getcwd()

# %%
# Loading dataset

fileName = 'survey_results_public.csv'
schemaName = 'survey_results_schema.csv'


df = pd.read_csv(fileName, index_col='ResponseId') 
schema_df = pd.read_csv(schemaName,index_col='qname')

# %%
# Filter a counties with high salarirs

high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary,['Country','LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                              Country  \
# ResponseId
# 13                           Germany
# 19                         Singapore
# 25                           Germany
# 27                       Switzerland
# 32                            Israel
# ...                              ...
# 83431       United States of America
# 83433                         Canada
# 83435       United States of America
# 83437       United States of America
# 83438                         Canada
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 13                                       C;C++;Java;Perl;Ruby
# 19                                                 C++;Python
# 25          C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...
# 27                                                 C++;Python
# 32                Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# ...                                                       ...
# ...

# %%
# Filtering by specific country

countries = ['United States of America','Sweden','Russian Federation']

filt1 = df['Country'].isin(countries)
df.loc[filt1]
# Out:
#                                                    MainBranch  \
# ResponseId
# 3           I am not primarily a developer, but I write co...
# 6                      I am a student who is learning to code
# 7                                 I code primarily as a hobby
# 10                             I am a developer by profession
# 16                     I am a student who is learning to code
# ...                                                       ...
# 83428                          I am a developer by profession
# 83430                             I code primarily as a hobby
# 83431                          I am a developer by profession
# 83435                          I am a developer by profession
# 83437                          I am a developer by profession
#
#                                     Employment                   Country  \
# ResponseId
# 3                           Student, full-time        Russian Federation
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
vis1 = sns.lmplot(data= df, x= 'CompTotal' , y='ConvertedCompYearly', fit_reg= False,height=6, aspect=1)

# %%
vis2 = sns.kdeplot(data= df[10:50] , x= 'CompTotal' ,y= 'ConvertedCompYearly', color='red',shade=True )
vis2b = sns.kdeplot(data= df[10:50] , x= 'CompTotal' ,y= 'ConvertedCompYearly', color='red' )

# %%
vis2 = sns.jointplot(data= df[10:50] , x= 'CompTotal' ,y= 'ConvertedCompYearly')

# %%
vis3 = sns.displot(data= df[:50] , x= 'CompTotal')

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize = (12,8),sharex=True,sharey=True)

vis1 = sns.kdeplot(data= df[10:50] ,x= 'ConvertedCompYearly', y= 'CompTotal' , color='red',shade=True ,ax =ax1)
vis1b = sns.kdeplot(data= df[10:50] ,x= 'ConvertedCompYearly', y= 'CompTotal' , color='red',ax =ax1 )



vis2 = sns.kdeplot(data= df[10:50] , x= 'CompTotal' ,y= 'ConvertedCompYearly', color='red',shade=True ,ax =ax2)
vis2b = sns.kdeplot(data= df[10:50] , x= 'CompTotal' ,y= 'ConvertedCompYearly', color='red',ax =ax2 )

# %%
wt = [55,65, 58] tvt in kgs
ht = [1.73, 1.89, 1.66] #ht in m
